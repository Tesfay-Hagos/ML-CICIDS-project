# %%
#1 fetch datas fromt he csv file if possible i have zip file in my google drive(tesfay.hagos1421@gmail.com) if not possible i will download and extract it

# %%
#2 then the data set is two i do not have any idea in what perspective they separated so check the data format and we have to decide.
